# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # This data is business corrections to previously published it consist of 78 rows and 5 columns in this data we have Series reference, Description, Period,Previously published, Revised

# %%
x = pd.read_csv("C://Users//mogil//Downloads//business-price-indexes-september-2020-quarter-corrections-to-previously-published-statistics.csv")
x
# Out:
#    Series reference                                        Description  \
# 0    PPIQ.SQU900000                 PPI output index - All industries
# 1    PPIQ.SQU900001         PPI output index - All industries excl OOD
# 2    PPIQ.SQUC76745  PPI published output commodity - Transport sup...
# 3    PPIQ.SQUCC3100  PPI output index level 3 - Wood product manufa...
# 4    PPIQ.SQUCC3110  PPI output index level 4 - Wood product manufa...
# ..              ...                                                ...
# 73   PPIQ.SQNMN2100  PPI input index level 3 - Administrative and s...
# 74   PPIQ.SQNRS211X     PPI input index level 4 - Repair & maintenance
# 75       FPIQ.SEC14  Farm expenses price index - Dairy farms - Freight
# 76       FPIQ.SEC99  Farm expenses price index - Dairy farms - All ...
# 77       FPIQ.SEH14    Farm expenses price index - All farms - Freight
#
#      Period  Previously published  Revised
# 0   2020.06                  1183     1184
# 1   2020.06                  1180     1181
# 2   2020.06                  1400     1603
# 3   2020.06                  1169     1170
# 4   2020.06                  1169     1170
# ..      ...                   ...      ...
# 73  2020.06                  1194     1195
# 74  2020.06                  1126     1127
# 75  2020.06                  1102     1120
# 76  2020.06                  1067     1068
# 77  2020.06                  1102     1110
#
# [78 rows x 5 columns]

# %%
x.describe()
# Out:
#              Period  Previously published      Revised
# count  7.800000e+01             78.000000    78.000000
# mean   2.020060e+03           1157.256410  1165.589744
# std    1.601918e-12             82.629581   100.669633
# min    2.020060e+03            903.000000   904.000000
# 25%    2.020060e+03           1124.500000  1126.250000
# 50%    2.020060e+03           1151.500000  1153.000000
# 75%    2.020060e+03           1192.750000  1194.250000
# max    2.020060e+03           1415.000000  1603.000000

# %%
x.corr()
# Out:
#                             Period  Previously published       Revised
# Period                1.000000e+00          1.136219e-15 -1.831908e-16
# Previously published  1.136219e-15          1.000000e+00  9.696490e-01
# Revised              -1.831908e-16          9.696490e-01  1.000000e+00

# %%
x.isnull().sum()
# Out:
# Series reference        0
# Description             0
# Period                  0
# Previously published    0
# Revised                 0
# dtype: int64

# %%
x.head()
# Out:
#   Series reference                                        Description  \
# 0   PPIQ.SQU900000                 PPI output index - All industries
# 1   PPIQ.SQU900001         PPI output index - All industries excl OOD
# 2   PPIQ.SQUC76745  PPI published output commodity - Transport sup...
# 3   PPIQ.SQUCC3100  PPI output index level 3 - Wood product manufa...
# 4   PPIQ.SQUCC3110  PPI output index level 4 - Wood product manufa...
#
#     Period  Previously published  Revised
# 0  2020.06                  1183     1184
# 1  2020.06                  1180     1181
# 2  2020.06                  1400     1603
# 3  2020.06                  1169     1170
# 4  2020.06                  1169     1170

# %%
x.tail()
# Out:
#    Series reference                                        Description  \
# 73   PPIQ.SQNMN2100  PPI input index level 3 - Administrative and s...
# 74   PPIQ.SQNRS211X     PPI input index level 4 - Repair & maintenance
# 75       FPIQ.SEC14  Farm expenses price index - Dairy farms - Freight
# 76       FPIQ.SEC99  Farm expenses price index - Dairy farms - All ...
# 77       FPIQ.SEH14    Farm expenses price index - All farms - Freight
#
#      Period  Previously published  Revised
# 73  2020.06                  1194     1195
# 74  2020.06                  1126     1127
# 75  2020.06                  1102     1120
# 76  2020.06                  1067     1068
# 77  2020.06                  1102     1110

# %%
x['% of deviation']=x['Previously published']/x['Revised']*100

# %%
x
# Out:
#    Series reference                                        Description  \
# 0    PPIQ.SQU900000                 PPI output index - All industries
# 1    PPIQ.SQU900001         PPI output index - All industries excl OOD
# 2    PPIQ.SQUC76745  PPI published output commodity - Transport sup...
# 3    PPIQ.SQUCC3100  PPI output index level 3 - Wood product manufa...
# 4    PPIQ.SQUCC3110  PPI output index level 4 - Wood product manufa...
# ..              ...                                                ...
# 73   PPIQ.SQNMN2100  PPI input index level 3 - Administrative and s...
# 74   PPIQ.SQNRS211X     PPI input index level 4 - Repair & maintenance
# 75       FPIQ.SEC14  Farm expenses price index - Dairy farms - Freight
# 76       FPIQ.SEC99  Farm expenses price index - Dairy farms - All ...
# 77       FPIQ.SEH14    Farm expenses price index - All farms - Freight
#
#      Period  Previously published  Revised  % of deviation
# 0   2020.06                  1183     1184       99.915541
# 1   2020.06                  1180     1181       99.915326
# 2   2020.06                  1400     1603       87.336245
# 3   2020.06                  1169     1170       99.914530
# 4   2020.06                  1169     1170       99.914530
# ..      ...                   ...      ...             ...
# 73  2020.06                  1194     1195       99.916318
# 74  2020.06                  1126     1127       99.911269
# 75  2020.06                  1102     1120       98.392857
# 76  2020.06                  1067     1068       99.906367
# 77  2020.06                  1102     1110       99.279279
#
# [78 rows x 6 columns]

# %% [markdown]
# # Here we can see the % of deviation after adding new column

# %%
max_deviation = x.sort_values(by='% of deviation', ascending=False)

# %%
max_deviation.head(10)
# Out:
#    Series reference                                        Description  \
# 49   PPIQ.SQNDD1200  PPI input index level 3 - Water, sewerage, dra...
# 19   PPIQ.SQURS2100          PPI output index level 3 - Other Services
# 18   PPIQ.SQURS2000          PPI output index level 2 - Other services
# 46   PPIQ.SQNCC912X      PPI input index level 4 - Other manufacturing
# 14   PPIQ.SQUII1200  PPI output index level 3 - Rail, water, air an...
# 47   PPIQ.SQNDD0000  PPI input index level 1 - Electricity, gas, wa...
# 48   PPIQ.SQNDD1000  PPI input index level 2 - Electricity, gas, wa...
# 70   PPIQ.SQNLL1100  PPI input index level 3 - Rental and hiring se...
# 32   PPIQ.SQNCC212X  PPI input index level 4 - Clothing, knitted pr...
# 71   PPIQ.SQNMN114X  PPI input index level 4 - Vet & other professi...
#
#      Period  Previously published  Revised  % of deviation
# 49  2020.06                  1282     1283       99.922058
# 19  2020.06                  1270     1271       99.921322
# 18  2020.06                  1270     1271       99.921322
# 46  2020.06                  1251     1252       99.920128
# 14  2020.06                  1237     1238       99.919225
# 47  2020.06                  1232     1233       99.918897
# 48  2020.06                  1232     1233       99.918897
# 70  2020.06                  1223     1224       99.918301
# 32  2020.06                  1212     1213       99.917560
# 71  2020.06                  1212     1213       99.917560

# %% [markdown]
# # Here we can see in % of deviation is less.
# The sectors we can see in Description those data is  updated almost same.
# As we can see by Previously published and Revised in above data.

# %%
max_deviation = x.sort_values(by='% of deviation', ascending=True)

# %%
max_deviation.head(10)
# Out:
#    Series reference                                        Description  \
# 2    PPIQ.SQUC76745  PPI published output commodity - Transport sup...
# 24   PPIQ.SQNC76745  PPI published input commodity - Transport supp...
# 15   PPIQ.SQUII1300  PPI output index level 3 - Postal, courier tra...
# 65   PPIQ.SQNII1300  PPI input index level 3 - Postal, courier tran...
# 75       FPIQ.SEC14  Farm expenses price index - Dairy farms - Freight
# 11   PPIQ.SQUII1000  PPI output index level 2 - Transport, postal a...
# 10   PPIQ.SQUII0000  PPI output index level 1 - Transport, postal a...
# 60   PPIQ.SQNII0000  PPI input index level 1 - Transport, postal an...
# 61   PPIQ.SQNII1000  PPI input index level 2 - Transport, postal an...
# 63   PPIQ.SQNII111X           PPI input index level 4 - Road transport
#
#      Period  Previously published  Revised  % of deviation
# 2   2020.06                  1400     1603       87.336245
# 24  2020.06                  1415     1568       90.242347
# 15  2020.06                  1269     1318       96.282246
# 65  2020.06                  1237     1262       98.019017
# 75  2020.06                  1102     1120       98.392857
# 11  2020.06                  1231     1249       98.558847
# 10  2020.06                  1231     1249       98.558847
# 60  2020.06                  1114     1124       99.110320
# 61  2020.06                  1114     1124       99.110320
# 63  2020.06                  1133     1142       99.211909

# %% [markdown]
# # Here we can see % of devation is slightly more
# The sectors we can see in Description those data is updated having slightly difference. As we can see by Previously published and Revised in above data.

# %%
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
import seaborn as sns

# %%
x.plot(kind = 'hist', x='Previously published',y='Revised' )

# %%
plt.bar(x['Previously published'], x['Revised']) 
plt.xlabel("Previously published") 
plt.ylabel("Revised") 
plt.show()

# %%
x.plot.bar()
